# %%
#Business problem statement + Data Merging
1. Inpatient + Outpatient = final_patient
2. final_patient + train = fp_v1
3. fp_v1 + beneficiary data = final data

# %%
# data merging
# EDA (Missing values, graphs, plots)
# Outlier treatments, Imputations
# Feature engineering
# Model Building
# Model Training 
# Model Evaluation

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
inpatient_data = pd.read_csv('Train_Inpatientdata.csv')
train = pd.read_csv('Train.csv')
ben_data = pd.read_csv('Train_Beneficiarydata.csv')

# %%
outpatient_data = pd.read_csv('Train_Outpatientdata.csv')

# %%
inpatient_data.describe()
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid  ClmProcedureCode_1  \
# count            40474.000000            39575.0        23148.000000
# mean             10087.884074             1068.0         5894.611759
# std              10303.099402                0.0         3049.304400
# min                  0.000000             1068.0           11.000000
# 25%               4000.000000             1068.0         3848.000000
# 50%               7000.000000             1068.0         5369.000000
# 75%              12000.000000             1068.0         8666.250000
# max             125000.000000             1068.0         9999.000000
#
#        ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# count         5454.000000          965.000000          116.000000
# mean          4103.738174         4226.355440         4070.172414
# std           2028.182156         2282.761581         1994.409802
# min             42.000000           42.000000           42.000000
# ...

# %%
inpatient_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40474 entries, 0 to 40473
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   BeneID                  40474 non-null  object
#  1   ClaimID                 40474 non-null  object
#  2   ClaimStartDt            40474 non-null  object
#  3   ClaimEndDt              40474 non-null  object
#  4   Provider                40474 non-null  object
#  5   InscClaimAmtReimbursed  40474 non-null  int64
#  6   AttendingPhysician      40362 non-null  object
#  7   OperatingPhysician      23830 non-null  object
#  8   OtherPhysician          4690 non-null   object
#  9   AdmissionDt             40474 non-null  object
#  10  ClmAdmitDiagnosisCode   40474 non-null  object
#  11  DeductibleAmtPaid       39575 non-null  float64
#  12  DischargeDt             40474 non-null  object
#  13  DiagnosisGroupCode      40474 non-null  object
# ...

# %%
40000, 
0 non-null in a column
no of null = no of rows - no of non null
          = 40000 - 0 = 40000

# %%
inpatient_data.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-04-12  ...               2724               19889
# 1            NaN  2009-08-31  ...                NaN                 NaN
# ...

# %%
outpatient_data.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   10/11/2009  10/11/2009  PRV56011
# 1  BENE11003  CLM189947    2/12/2009   2/12/2009  PRV57610
# 2  BENE11003  CLM438021    6/27/2009   6/27/2009  PRV57595
# 3  BENE11004  CLM121801     1/6/2009    1/6/2009  PRV56011
# 4  BENE11004  CLM150998    1/22/2009   1/22/2009  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0            NaN              78943  ...                NaN
# 1            NaN               6115  ...                NaN
# ...

# %%
outpatient_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517737 entries, 0 to 517736
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   BeneID                  517737 non-null  object
#  1   ClaimID                 517737 non-null  object
#  2   ClaimStartDt            517737 non-null  object
#  3   ClaimEndDt              517737 non-null  object
#  4   Provider                517737 non-null  object
#  5   InscClaimAmtReimbursed  517737 non-null  int64
#  6   AttendingPhysician      516341 non-null  object
#  7   OperatingPhysician      90617 non-null   object
#  8   OtherPhysician          195046 non-null  object
#  9   ClmDiagnosisCode_1      507284 non-null  object
#  10  ClmDiagnosisCode_2      322357 non-null  object
#  11  ClmDiagnosisCode_3      203257 non-null  object
#  12  ClmDiagnosisCode_4      125596 non-null  object
#  13  ClmDiagnosisCode_5      74344 non-null   object
# ...

# %%
train.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5410 entries, 0 to 5409
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provider        5410 non-null   object
#  1   PotentialFraud  5410 non-null   object
# dtypes: object(2)
# memory usage: 84.7+ KB

# %%
ben_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138556 entries, 0 to 138555
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           138556 non-null  object
#  1   DOB                              138556 non-null  object
#  2   DOD                              1421 non-null    object
#  3   Gender                           138556 non-null  int64
#  4   Race                             138556 non-null  int64
#  5   RenalDiseaseIndicator            138556 non-null  object
#  6   State                            138556 non-null  int64
#  7   County                           138556 non-null  int64
#  8   NoOfMonths_PartACov              138556 non-null  int64
#  9   NoOfMonths_PartBCov              138556 non-null  int64
#  10  ChronicCond_Alzheimer            138556 non-null  int64
# ...

# %%
ben_data.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0     230                   12                   12  ...
# 1     280                   12                   12  ...
# 2     590                   12                   12  ...
# 3     270                   12                   12  ...
# 4     680                   12                   12  ...
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# 0                       1                     1                          1
# ...

# %%
# final_patient_data = pd.merge(inpatient_data, outpatient_data, )

# %%
len(inpatient_data.columns.tolist())
# Out:
# 30

# %%
len(outpatient_data.columns.tolist())
# Out:
# 27

# %%
len([col_name for col_name in outpatient_data.columns.tolist() if col_name in inpatient_data.columns.tolist()])
# Out:
# 27

# %%
final_patient = pd.merge(inpatient_data, outpatient_data, 
left_on = [col for col in outpatient_data.columns if col in inpatient_data.columns],
right_on = [col for col in outpatient_data.columns if col in inpatient_data.columns]
, how = 'outer') #inner join, outer join(NA)

# %%
outpatient_data.shape
# Out:
# (517737, 27)

# %%
inpatient_data.shape
# Out:
# (40474, 30)

# %%
final_patient.shape
# Out:
# (558211, 30)

# %%
pd.set_option("display.max_columns", None)

# %%
final_patient.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# ...

# %%
final_patient['BeneID'].nunique()
# Out:
# 138556

# %%
ben_data['BeneID'].nunique()
# Out:
# 138556

# %%
ben_data.shape
# Out:
# (138556, 25)

# %%
final_ben = pd.merge(final_patient, ben_data, on = 'BeneID', how = 'inner')

# %%
final_ben.shape
# Out:
# (558211, 54)

# %%
final_ben.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11011  CLM144521    1/18/2009   1/18/2009  PRV52314
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                      50          PHY379398                NaN
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# ...

# %%
train['Provider'].nunique()
# Out:
# 5410

# %%
final_ben['Provider'].nunique()
# Out:
# 5410

# %%
final_ben.shape
# Out:
# (558211, 54)

# %%
final_data = pd.merge(final_ben, train, on = 'Provider', how = 'outer')

# %%
final_data.shape
# Out:
# (558211, 55)

# %%
final_data.head().transpose()
# Out:
#                                           0           1           2  \
# BeneID                            BENE11001   BENE16973   BENE17521
# ClaimID                            CLM46614   CLM565430    CLM34721
# ClaimStartDt                     2009-04-12    9/6/2009  2009-01-20
# ClaimEndDt                       2009-04-18    9/6/2009  2009-02-01
# Provider                           PRV55912    PRV55912    PRV55912
# InscClaimAmtReimbursed                26000          50       19000
# AttendingPhysician                PHY390922   PHY365867   PHY349293
# OperatingPhysician                      NaN   PHY327147   PHY370861
# OtherPhysician                          NaN         NaN   PHY363291
# AdmissionDt                      2009-04-12         NaN  2009-01-20
# ClmAdmitDiagnosisCode                  7866         NaN       45340
# DeductibleAmtPaid                      1068           0        1068
# DischargeDt                      2009-04-18         NaN  2009-02-01
# ...

# %%
# level binarizer

# %%
final_data['PotentialFraud'].value_counts()/len(final_data)*100
# Out:
# No     61.878931
# Yes    38.121069
# Name: PotentialFraud, dtype: float64

# %%
final_data['PotentialFraud'].value_counts(normalize = True)*100
# Out:
# No     61.878931
# Yes    38.121069
# Name: PotentialFraud, dtype: float64

# %%
for col in final_data.columns.tolist():
    print(final_data[col].value_counts())
# Out:
# BENE118316    29
# BENE42721     29
# BENE59303     29
# BENE36330     28
# BENE44241     28
#               ..
# BENE131170     1
# BENE75322      1
# BENE105639     1
# BENE34774      1
# BENE138338     1
# Name: BeneID, Length: 138556, dtype: int64
# CLM583568    1
# CLM349683    1
# CLM572414    1
# CLM665991    1
# CLM704775    1
#             ..
# CLM180171    1
# CLM723724    1
# CLM588072    1
# CLM654168    1
# CLM204418    1
# Name: ClaimID, Length: 558211, dtype: int64
# 3/3/2009      1574
# 3/21/2009     1567
# 1/31/2009     1566
# 4/25/2009     1550
# 2/16/2009     1549
#               ...
# 2008-12-07       2
# 2008-12-10       1
# 2008-12-03       1
# 2009-12-31       1
# 2008-12-06       1
# Name: ClaimStartDt, Length: 783, dtype: int64
# 3/3/2009      1563
# 3/21/2009     1561
# 4/23/2009     1554
# 5/1/2009      1548
# 6/20/2009     1542
#               ...
# 2009-12-23      82
# 2009-10-19      79
# 2009-11-11      77
# 2009-12-25      75
# 12/28/2008       1
# ...

# %%
final_data['ClmProcedureCode_6'].value_counts() #col 2 be removed
# Out:
# Series([], Name: ClmProcedureCode_6, dtype: int64)

# %%
#Feature engineering and data pre-processing

# %%
inpatient_data.shape
# Out:
# (40474, 30)

# %%
inpatient_data['Provider'].nunique()
# Out:
# 2092

# %%
train.shape
# Out:
# (5410, 2)

# %%
train_inpatient = pd.merge(inpatient_data, train, how = "outer", on = 'Provider')

# %%
train_inpatient.shape
# Out:
# (43792, 31)

# %%
non_inpatient = np.setdiff1d(np.array(train['Provider']), np.array(inpatient_data['Provider']))

# %%
len(non_inpatient)
# Out:
# 3318

# %%
non_inpatient
# Out:
# array(['PRV51004', 'PRV51005', 'PRV51012', ..., 'PRV57761', 'PRV57762',
#        'PRV57763'], dtype=object)

# %%
5410 - 2092 + 40474
# Out:
# 43792

# %%
train_inpatient.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE17521  CLM34721   2009-01-20  2009-02-01  PRV55912
# 2  BENE21718  CLM72336   2009-10-17  2009-11-04  PRV55912
# 3  BENE22934  CLM73394   2009-10-25  2009-10-29  PRV55912
# 4  BENE24402  CLM32911   2009-01-08  2009-01-12  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                 26000.0          PHY390922                NaN
# 1                 19000.0          PHY349293          PHY370861
# 2                 17000.0          PHY334706          PHY334706
# 3                 13000.0          PHY390614          PHY323689
# 4                  3000.0          PHY380413          PHY432598
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1      PHY363291  2009-01-20                 45340             1068.0
# ...

# %%
train_inpatient['PotentialFraud'].value_counts()
# Out:
# Yes    23468
# No     20324
# Name: PotentialFraud, dtype: int64

# %%
train_inpatient[train_inpatient['Provider'] == 'PRV51004']
# Out:
#       BeneID ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 40474    NaN     NaN          NaN        NaN  PRV51004
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 40474                     NaN                NaN                NaN
#
#       OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 40474            NaN         NaN                   NaN                NaN
#
#       DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 40474         NaN                NaN                NaN                NaN
#
#       ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 40474                NaN                NaN                NaN
#
#       ClmDiagnosisCode_6 ClmDiagnosisCode_7 ClmDiagnosisCode_8  \
# 40474                NaN                NaN                NaN
#
#       ClmDiagnosisCode_9 ClmDiagnosisCode_10  ClmProcedureCode_1  \
# 40474                NaN                 NaN                 NaN
#
# ...

# %%
train_outpatient = pd.merge(outpatient_data, train, how = "outer", on = 'Provider')

# %%
train_outpatient.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   10/11/2009  10/11/2009  PRV56011
# 1  BENE11004  CLM121801     1/6/2009    1/6/2009  PRV56011
# 2  BENE11004  CLM150998    1/22/2009   1/22/2009  PRV56011
# 3  BENE11004  CLM173224     2/3/2009    2/3/2009  PRV56011
# 4  BENE11004  CLM224741     3/3/2009    3/3/2009  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    30.0          PHY326117                NaN
# 1                    40.0          PHY334319                NaN
# 2                   200.0          PHY403831                NaN
# 3                    20.0          PHY339887                NaN
# 4                    40.0          PHY345721                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0            NaN              78943              V5866              V1272
# ...

# %%
outpatient_data.shape
# Out:
# (517737, 27)

# %%
train.shape
# Out:
# (5410, 2)

# %%
train_outpatient.shape
# Out:
# (518135, 28)

# %%
final_data.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE16973  CLM565430     9/6/2009    9/6/2009  PRV55912
# 2  BENE17521   CLM34721   2009-01-20  2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17  2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25  2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                      50          PHY365867          PHY327147
# 2                   19000          PHY349293          PHY370861
# 3                   17000          PHY334706          PHY334706
# 4                   13000          PHY390614          PHY323689
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN         NaN                   NaN                0.0
# ...

# %%
#series to dictionary
physician_count = final_data['AttendingPhysician'].value_counts().to_dict()

# %%
physician_count
# Out:
# {'PHY330576': 2534,
#  'PHY350277': 1628,
#  'PHY412132': 1321,
#  'PHY423534': 1223,
#  'PHY314027': 1200,
#  'PHY327046': 1181,
#  'PHY338032': 1158,
#  'PHY337425': 1156,
#  'PHY357120': 1156,
#  'PHY341578': 1133,
#  'PHY432650': 1093,
#  'PHY347064': 1076,
#  'PHY351121': 1053,
#  'PHY383481': 1005,
#  'PHY415321': 1002,
#  'PHY344389': 1000,
#  'PHY433436': 924,
#  'PHY375943': 912,
#  'PHY375453': 880,
#  'PHY387126': 762,
#  'PHY357307': 737,
#  'PHY432614': 716,
#  'PHY318667': 711,
#  'PHY424712': 693,
#  'PHY326984': 686,
#  'PHY347780': 678,
#  'PHY313278': 674,
#  'PHY362889': 674,
#  'PHY389456': 673,
#  'PHY323447': 664,
#  'PHY387026': 647,
#  'PHY368630': 637,
#  'PHY367255': 634,
#  'PHY333735': 634,
#  'PHY360043': 627,
#  'PHY373032': 618,
#  'PHY381249': 615,
#  'PHY375219': 609,
#  'PHY356444': 600,
#  'PHY404832': 596,
#  'PHY418434': 585,
#  'PHY360179': 583,
#  'PHY385072': 582,
#  'PHY339530': 569,
#  'PHY341452': 561,
#  'PHY325906': 547,
# ...

# %%
provider_count = final_data['Provider'].value_counts().to_dict()

# %%
provider_count
# Out:
# {'PRV51459': 8240,
#  'PRV53797': 4739,
#  'PRV51574': 4444,
#  'PRV53918': 3588,
#  'PRV54895': 3436,
#  'PRV55215': 3393,
#  'PRV52064': 2844,
#  'PRV56011': 2833,
#  'PRV55004': 2399,
#  'PRV57306': 2315,
#  'PRV56560': 2313,
#  'PRV52030': 2275,
#  'PRV52649': 2156,
#  'PRV54772': 2115,
#  'PRV52628': 2098,
#  'PRV51369': 2083,
#  'PRV51347': 2067,
#  'PRV55039': 2058,
#  'PRV57103': 2049,
#  'PRV52019': 1961,
#  'PRV51480': 1924,
#  'PRV55462': 1907,
#  'PRV55467': 1896,
#  'PRV54742': 1892,
#  'PRV52041': 1885,
#  'PRV54837': 1843,
#  'PRV54966': 1796,
#  'PRV51836': 1794,
#  'PRV56689': 1794,
#  'PRV57172': 1760,
#  'PRV52340': 1743,
#  'PRV54778': 1672,
#  'PRV51567': 1632,
#  'PRV54372': 1617,
#  'PRV51433': 1610,
#  'PRV56416': 1592,
#  'PRV54075': 1519,
#  'PRV51578': 1500,
#  'PRV57191': 1500,
#  'PRV54350': 1495,
#  'PRV54070': 1467,
#  'PRV52066': 1455,
#  'PRV51244': 1415,
#  'PRV52985': 1403,
#  'PRV53786': 1382,
#  'PRV54939': 1380,
#  'PRV56008': 1370,
# ...

# %%
ben_count = final_data['BeneID'].value_counts().to_dict()

# %%
ben_count
# Out:
# {'BENE118316': 29,
#  'BENE42721': 29,
#  'BENE59303': 29,
#  'BENE36330': 28,
#  'BENE44241': 28,
#  'BENE80977': 28,
#  'BENE40202': 27,
#  'BENE63504': 27,
#  'BENE143400': 27,
#  'BENE63544': 27,
#  'BENE87248': 27,
#  'BENE126421': 26,
#  'BENE111593': 26,
#  'BENE135580': 26,
#  'BENE122118': 26,
#  'BENE64472': 25,
#  'BENE158374': 25,
#  'BENE66093': 25,
#  'BENE121514': 25,
#  'BENE111306': 25,
#  'BENE81944': 25,
#  'BENE97876': 25,
#  'BENE130030': 24,
#  'BENE28733': 24,
#  'BENE34822': 24,
#  'BENE151631': 24,
#  'BENE113804': 24,
#  'BENE140460': 24,
#  'BENE17000': 24,
#  'BENE146725': 24,
#  'BENE87910': 23,
#  'BENE37190': 23,
#  'BENE15365': 23,
#  'BENE142949': 23,
#  'BENE136191': 23,
#  'BENE17168': 23,
#  'BENE128901': 23,
#  'BENE69984': 23,
#  'BENE152793': 23,
#  'BENE102984': 23,
#  'BENE48451': 23,
#  'BENE114936': 23,
#  'BENE155807': 23,
#  'BENE55210': 23,
#  'BENE107847': 23,
#  'BENE46215': 23,
#  'BENE153814': 23,
#  'BENE67593': 23,
# ...

# %%
final_data.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE16973  CLM565430     9/6/2009    9/6/2009  PRV55912
# 2  BENE17521   CLM34721   2009-01-20  2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17  2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25  2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                      50          PHY365867          PHY327147
# 2                   19000          PHY349293          PHY370861
# 3                   17000          PHY334706          PHY334706
# 4                   13000          PHY390614          PHY323689
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN         NaN                   NaN                0.0
# ...

# %%
final_data['physician_count'] = final_data['AttendingPhysician'].map(physician_count)

# %%
final_data.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE16973  CLM565430     9/6/2009    9/6/2009  PRV55912
# 2  BENE17521   CLM34721   2009-01-20  2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17  2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25  2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                      50          PHY365867          PHY327147
# 2                   19000          PHY349293          PHY370861
# 3                   17000          PHY334706          PHY334706
# 4                   13000          PHY390614          PHY323689
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN         NaN                   NaN                0.0
# ...

# %%
physician_count['PHY390922']
# Out:
# 1

# %%
final_data[final_data['AttendingPhysician'] == "PHY330576"]
# Out:
#            BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 28184   BENE11066  CLM443527    6/30/2009   7/20/2009  PRV53918
# 28185   BENE11066  CLM470441    7/15/2009   7/15/2009  PRV53918
# 28187   BENE12065  CLM154715    1/24/2009   1/24/2009  PRV53918
# 28190   BENE12136  CLM577544    9/13/2009   9/13/2009  PRV53918
# 28191   BENE12136  CLM601511    9/27/2009   9/27/2009  PRV53918
# ...           ...        ...          ...         ...       ...
# 31766  BENE159013  CLM395945     6/3/2009    6/3/2009  PRV53918
# 31767  BENE159118  CLM174165     2/3/2009    2/3/2009  PRV53918
# 31768  BENE159159  CLM321770    4/24/2009   4/24/2009  PRV53918
# 31770  BENE159159  CLM645284   10/23/2009  10/23/2009  PRV53918
# 31771  BENE159171  CLM284891     4/4/2009    4/4/2009  PRV53918
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 28184                      60          PHY330576                NaN
# ...

# %%
physician_count['PHY330576']
# Out:
# 2534

# %%
final_data['provider_count'] = final_data['Provider'].map(provider_count)

# %%
final_data['ben_count'] = final_data['BeneID'].map(ben_count)

# %%
final_data.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE16973  CLM565430     9/6/2009    9/6/2009  PRV55912
# 2  BENE17521   CLM34721   2009-01-20  2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17  2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25  2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                      50          PHY365867          PHY327147
# 2                   19000          PHY349293          PHY370861
# 3                   17000          PHY334706          PHY334706
# 4                   13000          PHY390614          PHY323689
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN         NaN                   NaN                0.0
# ...

# %%
train_inpatient.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE17521  CLM34721   2009-01-20  2009-02-01  PRV55912
# 2  BENE21718  CLM72336   2009-10-17  2009-11-04  PRV55912
# 3  BENE22934  CLM73394   2009-10-25  2009-10-29  PRV55912
# 4  BENE24402  CLM32911   2009-01-08  2009-01-12  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                 26000.0          PHY390922                NaN
# 1                 19000.0          PHY349293          PHY370861
# 2                 17000.0          PHY334706          PHY334706
# 3                 13000.0          PHY390614          PHY323689
# 4                  3000.0          PHY380413          PHY432598
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1      PHY363291  2009-01-20                 45340             1068.0
# ...

# %%
train_inpatient['AdmissionDt'][0]
# Out:
# '2009-04-12'

# %%
train_inpatient['DischargeDt'][0]
# Out:
# '2009-04-18'

# %%
train_inpatient['AdmissionDt'] = pd.to_datetime(train_inpatient['AdmissionDt'])

# %%
train_inpatient.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE17521  CLM34721   2009-01-20  2009-02-01  PRV55912
# 2  BENE21718  CLM72336   2009-10-17  2009-11-04  PRV55912
# 3  BENE22934  CLM73394   2009-10-25  2009-10-29  PRV55912
# 4  BENE24402  CLM32911   2009-01-08  2009-01-12  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                 26000.0          PHY390922                NaN
# 1                 19000.0          PHY349293          PHY370861
# 2                 17000.0          PHY334706          PHY334706
# 3                 13000.0          PHY390614          PHY323689
# 4                  3000.0          PHY380413          PHY432598
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1      PHY363291  2009-01-20                 45340             1068.0
# ...

# %%
train_inpatient['AdmissionDt'][0]
# Out:
# Timestamp('2009-04-12 00:00:00')

# %%
train_inpatient['DischargeDt'] = pd.to_datetime(train_inpatient['DischargeDt'])

# %%
train_inpatient['AdmissionDt'][0]
# Out:
# Timestamp('2009-04-12 00:00:00')

# %%
train_inpatient['numofdaysadmitted'] = train_inpatient['DischargeDt'] - train_inpatient['AdmissionDt']

# %%
train_inpatient.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE17521  CLM34721   2009-01-20  2009-02-01  PRV55912
# 2  BENE21718  CLM72336   2009-10-17  2009-11-04  PRV55912
# 3  BENE22934  CLM73394   2009-10-25  2009-10-29  PRV55912
# 4  BENE24402  CLM32911   2009-01-08  2009-01-12  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                 26000.0          PHY390922                NaN
# 1                 19000.0          PHY349293          PHY370861
# 2                 17000.0          PHY334706          PHY334706
# 3                 13000.0          PHY390614          PHY323689
# 4                  3000.0          PHY380413          PHY432598
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1      PHY363291  2009-01-20                 45340             1068.0
# ...

# %%
train_inpatient['numofdaysadmitted'].value_counts()
# Out:
# 3 days     6902
# 2 days     6117
# 4 days     4994
# 1 days     4591
# 5 days     3579
# 6 days     2719
# 7 days     2206
# 8 days     1613
# 9 days     1151
# 10 days     917
# 11 days     726
# 0 days      605
# 12 days     582
# 13 days     518
# 14 days     462
# 15 days     387
# 35 days     337
# 16 days     306
# 17 days     286
# 18 days     212
# 19 days     174
# 21 days     147
# 20 days     146
# 22 days     121
# 23 days     103
# 24 days      80
# 27 days      77
# 28 days      72
# 25 days      68
# 26 days      68
# 29 days      42
# 32 days      40
# 33 days      38
# 30 days      36
# 34 days      28
# 31 days      24
# Name: numofdaysadmitted, dtype: int64

# %%
train_inpatient['numofdaysadmitted']
# Out:
# 0        6 days
# 1       12 days
# 2       18 days
# 3        4 days
# 4        4 days
#           ...
# 43787       NaT
# 43788       NaT
# 43789       NaT
# 43790       NaT
# 43791       NaT
# Name: numofdaysadmitted, Length: 43792, dtype: timedelta64[ns]

# %%
train_inpatient['numofdaysadmitted'].isnull() #.isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 43787     True
# 43788     True
# 43789     True
# 43790     True
# 43791     True
# Name: numofdaysadmitted, Length: 43792, dtype: bool

# %%
train_inpatient['numofdaysadmitted'].replace({pd.NaT : "0 days"}, inplace = True)

# %%
train_inpatient['numofdaysadmitted']
# Out:
# 0         6 days 00:00:00
# 1        12 days 00:00:00
# 2        18 days 00:00:00
# 3         4 days 00:00:00
# 4         4 days 00:00:00
#                ...
# 43787              0 days
# 43788              0 days
# 43789              0 days
# 43790              0 days
# 43791              0 days
# Name: numofdaysadmitted, Length: 43792, dtype: object

# %%
train_inpatient['numofdaysadmitted'].astype(str)
# Out:
# 0         6 days 00:00:00
# 1        12 days 00:00:00
# 2        18 days 00:00:00
# 3         4 days 00:00:00
# 4         4 days 00:00:00
#                ...
# 43787              0 days
# 43788              0 days
# 43789              0 days
# 43790              0 days
# 43791              0 days
# Name: numofdaysadmitted, Length: 43792, dtype: object

# %%
train_inpatient['numofdaysadmitted'].astype(str).map(lambda x: int(x.split(" ")[0]))
# Out:
# 0         6
# 1        12
# 2        18
# 3         4
# 4         4
#          ..
# 43787     0
# 43788     0
# 43789     0
# 43790     0
# 43791     0
# Name: numofdaysadmitted, Length: 43792, dtype: int64

# %%
train_inpatient['numofdaysadmitted'] = train_inpatient['numofdaysadmitted'].astype(str).map(lambda x: int(x.split(" ")[0]))

# %%
train_inpatient.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE17521  CLM34721   2009-01-20  2009-02-01  PRV55912
# 2  BENE21718  CLM72336   2009-10-17  2009-11-04  PRV55912
# 3  BENE22934  CLM73394   2009-10-25  2009-10-29  PRV55912
# 4  BENE24402  CLM32911   2009-01-08  2009-01-12  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                 26000.0          PHY390922                NaN
# 1                 19000.0          PHY349293          PHY370861
# 2                 17000.0          PHY334706          PHY334706
# 3                 13000.0          PHY390614          PHY323689
# 4                  3000.0          PHY380413          PHY432598
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1      PHY363291  2009-01-20                 45340             1068.0
# ...

# %%
train_inpatient['physician_count'] = train_inpatient['AttendingPhysician'].map(physician_count)

# %%
train_inpatient.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE17521  CLM34721   2009-01-20  2009-02-01  PRV55912
# 2  BENE21718  CLM72336   2009-10-17  2009-11-04  PRV55912
# 3  BENE22934  CLM73394   2009-10-25  2009-10-29  PRV55912
# 4  BENE24402  CLM32911   2009-01-08  2009-01-12  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                 26000.0          PHY390922                NaN
# 1                 19000.0          PHY349293          PHY370861
# 2                 17000.0          PHY334706          PHY334706
# 3                 13000.0          PHY390614          PHY323689
# 4                  3000.0          PHY380413          PHY432598
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1      PHY363291  2009-01-20                 45340             1068.0
# ...

# %%
final_data.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE16973  CLM565430     9/6/2009    9/6/2009  PRV55912
# 2  BENE17521   CLM34721   2009-01-20  2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17  2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25  2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                      50          PHY365867          PHY327147
# 2                   19000          PHY349293          PHY370861
# 3                   17000          PHY334706          PHY334706
# 4                   13000          PHY390614          PHY323689
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN         NaN                   NaN                0.0
# ...

# %%
for col in final_data.columns.tolist():
    print("col name", col)
    print(final_data[col].value_counts())
# Out:
# col name BeneID
# BENE118316    29
# BENE42721     29
# BENE59303     29
# BENE36330     28
# BENE44241     28
#               ..
# BENE131170     1
# BENE75322      1
# BENE105639     1
# BENE34774      1
# BENE138338     1
# Name: BeneID, Length: 138556, dtype: int64
# col name ClaimID
# CLM583568    1
# CLM349683    1
# CLM572414    1
# CLM665991    1
# CLM704775    1
#             ..
# CLM180171    1
# CLM723724    1
# CLM588072    1
# CLM654168    1
# CLM204418    1
# Name: ClaimID, Length: 558211, dtype: int64
# col name ClaimStartDt
# 3/3/2009      1574
# 3/21/2009     1567
# 1/31/2009     1566
# 4/25/2009     1550
# 2/16/2009     1549
#               ...
# 2008-12-07       2
# 2008-12-10       1
# 2008-12-03       1
# 2009-12-31       1
# 2008-12-06       1
# Name: ClaimStartDt, Length: 783, dtype: int64
# col name ClaimEndDt
# 3/3/2009      1563
# 3/21/2009     1561
# 4/23/2009     1554
# 5/1/2009      1548
# 6/20/2009     1542
#               ...
# 2009-12-23      82
# ...

# %%
final_data['ClmProcedureCode_3'].isnull().sum()
# Out:
# 557242

# %%
final_data['ClmProcedureCode_3'].value_counts()
# Out:
# 4019.0    201
# 2724.0    192
# 5849.0     42
# 4439.0     29
# 9971.0     27
#          ...
# 1509.0      1
# 400.0       1
# 1622.0      1
# 6822.0      1
# 4532.0      1
# Name: ClmProcedureCode_3, Length: 154, dtype: int64

# %%
final_data.shape
# Out:
# (558211, 58)

# %%
final_data['ClmProcedureCode_2'].isnull().sum()/len(final_data)*100
# Out:
# 99.01650092886022

# %%
final_data['ClmProcedureCode_1'].isnull().sum()/len(final_data)*100
# Out:
# 95.82415968155411

# %%
final_data['ClmProcedureCode_3'].isnull().sum()/len(final_data)*100
# Out:
# 99.8264097267879

# %%
final_data['ClmProcedureCode_4'].isnull().sum()/len(final_data)*100
# Out:
# 99.978861040001

# %%
final_data['ClmProcedureCode_5'].isnull().sum()/len(final_data)*100
# Out:
# 99.99838770644075

# %%
final_data['ClmProcedureCode_6'].isnull().sum()/len(final_data)*100
# Out:
# 100.0

# %%
final_data['NoOfMonths_PartBCov'].isnull().sum()/len(final_data)*100
# Out:
# 0.0

# %%
final_data['NoOfMonths_PartBCov'].value_counts(normalize = True)*100
# Out:
# 12    99.230936
# 0      0.354525
# 6      0.130417
# 10     0.072016
# 11     0.056072
# 9      0.043353
# 8      0.025438
# 7      0.024901
# 5      0.022572
# 3      0.013077
# 4      0.010749
# 1      0.008599
# 2      0.007345
# Name: NoOfMonths_PartBCov, dtype: float64

# %%
final_data['NoOfMonths_PartACov'].value_counts(normalize = True)*100
# Out:
# 12    99.374968
# 0      0.532236
# 6      0.020781
# 8      0.017914
# 11     0.014511
# 4      0.009853
# 7      0.007882
# 10     0.006091
# 5      0.005374
# 3      0.002866
# 2      0.002866
# 9      0.002329
# 1      0.002329
# Name: NoOfMonths_PartACov, dtype: float64

# %%
#If 95% of the data belongs to single value, then there is no importance of that column in prediction

# %%
final_data.isnull().sum()/len(final_data)*100
# Out:
# BeneID                               0.000000
# ClaimID                              0.000000
# ClaimStartDt                         0.000000
# ClaimEndDt                           0.000000
# Provider                             0.000000
# InscClaimAmtReimbursed               0.000000
# AttendingPhysician                   0.270149
# OperatingPhysician                  79.497538
# OtherPhysician                      64.218548
# AdmissionDt                         92.749337
# ClmAdmitDiagnosisCode               73.863109
# DeductibleAmtPaid                    0.161050
# DischargeDt                         92.749337
# DiagnosisGroupCode                  92.749337
# ClmDiagnosisCode_1                   1.872589
# ClmDiagnosisCode_2                  35.041588
# ClmDiagnosisCode_3                  56.458221
# ClmDiagnosisCode_4                  70.524407
# ClmDiagnosisCode_5                  79.949517
# ClmDiagnosisCode_6                  84.881702
# ...

# %%
for col in ['AttendingPhysician', 'DeductibleAmtPaid', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'physician_count']:
    print("column: ", col)
    print(final_data[col].value_counts(normalize = True))
# Out:
# column:  AttendingPhysician
# PHY330576    0.004552
# PHY350277    0.002924
# PHY412132    0.002373
# PHY423534    0.002197
# PHY314027    0.002156
#                ...
# PHY377889    0.000002
# PHY343319    0.000002
# PHY366245    0.000002
# PHY424298    0.000002
# PHY341266    0.000002
# Name: AttendingPhysician, Length: 82063, dtype: float64
# column:  DeductibleAmtPaid
# 0.0       0.891244
# 1068.0    0.071010
# 100.0     0.008222
# 70.0      0.004342
# 60.0      0.003705
# 40.0      0.003669
# 80.0      0.003632
# 50.0      0.003533
# 20.0      0.002523
# 30.0      0.002397
# 90.0      0.002234
# 10.0      0.002159
# 200.0     0.001317
# 897.0     0.000004
# 876.0     0.000004
# 865.0     0.000004
# 886.0     0.000002
# Name: DeductibleAmtPaid, dtype: float64
# column:  ClmDiagnosisCode_1
# 4019     0.025351
# 4011     0.022842
# 2724     0.006583
# 2720     0.005860
# 2722     0.005528
#            ...
# 86353    0.000002
# 37613    0.000002
# 80486    0.000002
# ...

# %%
final_data1 = final_data.drop(['NoOfMonths_PartACov','NoOfMonths_PartBCov','ClmProcedureCode_6','ClmProcedureCode_5',
                              'ClmProcedureCode_4','ClmProcedureCode_3','ClmProcedureCode_2', 'ClmProcedureCode_1',
                              'DOD','ClmDiagnosisCode_10','ClmDiagnosisCode_9','ClmDiagnosisCode_8','ClmDiagnosisCode_7',
                               'ClmDiagnosisCode_6','ClmDiagnosisCode_5','ClmDiagnosisCode_4', 'ClmDiagnosisCode_3', 
                               'DiagnosisGroupCode','DischargeDt', 'ClmAdmitDiagnosisCode', 'AdmissionDt',
                               'OtherPhysician', 'OperatingPhysician','DeductibleAmtPaid'], axis = 1)

# %%
final_data1.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE16973  CLM565430     9/6/2009    9/6/2009  PRV55912
# 2  BENE17521   CLM34721   2009-01-20  2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17  2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25  2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician ClmDiagnosisCode_1  \
# 0                   26000          PHY390922               1970
# 1                      50          PHY365867              V7183
# 2                   19000          PHY349293               4240
# 3                   17000          PHY334706              V5789
# 4                   13000          PHY390614              71535
#
#   ClmDiagnosisCode_2         DOB  Gender  Race RenalDiseaseIndicator  State  \
# 0               4019  1943-01-01       1     1                     0     39
# ...

# %%
final_data1.describe()
# Out:
#        InscClaimAmtReimbursed         Gender           Race          State  \
# count           558211.000000  558211.000000  558211.000000  558211.000000
# mean               997.012133       1.578838       1.255011      25.446969
# std               3821.534891       0.493746       0.717437      15.192784
# min                  0.000000       1.000000       1.000000       1.000000
# 25%                 40.000000       1.000000       1.000000      11.000000
# 50%                 80.000000       2.000000       1.000000      24.000000
# 75%                300.000000       2.000000       1.000000      38.000000
# max             125000.000000       2.000000       5.000000      54.000000
#
#               County  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# count  558211.000000          558211.000000             558211.000000
# mean      378.588195               1.598132                  1.409573
# std       265.215531               0.490276                  0.491755
# ...

# %%
final_data1.shape
# Out:
# (558211, 34)

# %%
final_data1.isnull().sum()/len(final_data1)*100
# Out:
# BeneID                              0.000000
# ClaimID                             0.000000
# ClaimStartDt                        0.000000
# ClaimEndDt                          0.000000
# Provider                            0.000000
# InscClaimAmtReimbursed              0.000000
# AttendingPhysician                  0.270149
# ClmDiagnosisCode_1                  1.872589
# ClmDiagnosisCode_2                 35.041588
# DOB                                 0.000000
# Gender                              0.000000
# Race                                0.000000
# RenalDiseaseIndicator               0.000000
# State                               0.000000
# County                              0.000000
# ChronicCond_Alzheimer               0.000000
# ChronicCond_Heartfailure            0.000000
# ChronicCond_KidneyDisease           0.000000
# ChronicCond_Cancer                  0.000000
# ChronicCond_ObstrPulmonary          0.000000
# ChronicCond_Depression              0.000000
# ...

# %%
for c in ['AttendingPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'physician_count']:
    final_data1[c] = final_data1[c].replace({np.nan:0})

# %%
# there can be columns which already hv 0 (they're not nan) now replacing nan with 0s 

# hw much % of 0s r there in the columns

# 0s also mean something,

# %%
final_data1.isnull().sum()/len(final_data1)*100
# Out:
# BeneID                             0.0
# ClaimID                            0.0
# ClaimStartDt                       0.0
# ClaimEndDt                         0.0
# Provider                           0.0
# InscClaimAmtReimbursed             0.0
# AttendingPhysician                 0.0
# ClmDiagnosisCode_1                 0.0
# ClmDiagnosisCode_2                 0.0
# DOB                                0.0
# Gender                             0.0
# Race                               0.0
# RenalDiseaseIndicator              0.0
# State                              0.0
# County                             0.0
# ChronicCond_Alzheimer              0.0
# ChronicCond_Heartfailure           0.0
# ChronicCond_KidneyDisease          0.0
# ChronicCond_Cancer                 0.0
# ChronicCond_ObstrPulmonary         0.0
# ChronicCond_Depression             0.0
# ChronicCond_Diabetes               0.0
# ChronicCond_IschemicHeart          0.0
# ChronicCond_Osteoporasis           0.0
# ...

# %%
for col in ['AttendingPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'physician_count']:
    print("column: ", col)
    print(final_data1[col].value_counts(normalize = True))
# Out:
# column:  AttendingPhysician
# PHY330576    0.004540
# PHY350277    0.002916
# 0            0.002701
# PHY412132    0.002366
# PHY423534    0.002191
#                ...
# PHY356622    0.000002
# PHY428797    0.000002
# PHY377889    0.000002
# PHY343319    0.000002
# PHY335008    0.000002
# Name: AttendingPhysician, Length: 82064, dtype: float64
# column:  ClmDiagnosisCode_1
# 4019     0.024876
# 4011     0.022414
# 0        0.018726
# 2724     0.006460
# 2720     0.005751
#            ...
# 80022    0.000002
# 94402    0.000002
# 80179    0.000002
# 80224    0.000002
# 80066    0.000002
# Name: ClmDiagnosisCode_1, Length: 10372, dtype: float64
# column:  ClmDiagnosisCode_2
# 0        0.350416
# 4019     0.040089
# 25000    0.021039
# 2724     0.020193
# V5861    0.017406
#            ...
# 71885    0.000002
# 36242    0.000002
# 37049    0.000002
# 8760     0.000002
# 1504     0.000002
# Name: ClmDiagnosisCode_2, Length: 5327, dtype: float64
# column:  physician_count
# ...

# %%
final_data1['physician_count'] = final_data1['physician_count'].replace(0, 1.0)
final_data1['ClmDiagnosisCode_2'] = final_data1['ClmDiagnosisCode_2'].replace(0, '4019') 
final_data1['ClmDiagnosisCode_1'] = final_data1['ClmDiagnosisCode_1'].replace(0, '4019')

# %%
final_data1['AttendingPhysician'] = final_data['AttendingPhysician'].replace(0, 'PHY330576')

# %%
final_data1.shape
# Out:
# (558211, 34)

# %%
final_data1.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE16973  CLM565430     9/6/2009    9/6/2009  PRV55912
# 2  BENE17521   CLM34721   2009-01-20  2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17  2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25  2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician ClmDiagnosisCode_1  \
# 0                   26000          PHY390922               1970
# 1                      50          PHY365867              V7183
# 2                   19000          PHY349293               4240
# 3                   17000          PHY334706              V5789
# 4                   13000          PHY390614              71535
#
#   ClmDiagnosisCode_2         DOB  Gender  Race RenalDiseaseIndicator  State  \
# 0               4019  1943-01-01       1     1                     0     39
# ...

# %%
def binary_columns():
    empty = []
    for i in final_data1.columns.tolist():
        if final_data1[i].nunique() <= 2:
            empty.append(i)
    return empty

# %%
b_cols = binary_columns()
b_cols
# Out:
# ['Gender',
#  'RenalDiseaseIndicator',
#  'ChronicCond_Alzheimer',
#  'ChronicCond_Heartfailure',
#  'ChronicCond_KidneyDisease',
#  'ChronicCond_Cancer',
#  'ChronicCond_ObstrPulmonary',
#  'ChronicCond_Depression',
#  'ChronicCond_Diabetes',
#  'ChronicCond_IschemicHeart',
#  'ChronicCond_Osteoporasis',
#  'ChronicCond_rheumatoidarthritis',
#  'ChronicCond_stroke',
#  'PotentialFraud']

# %%
for column in b_cols:
    print("col name: ", column)
    print(final_data1[column].value_counts(normalize = True)*100)
# Out:
# col name:  Gender
# 2    57.883847
# 1    42.116153
# Name: Gender, dtype: float64
# col name:  RenalDiseaseIndicator
# 0    80.32142
# Y    19.67858
# Name: RenalDiseaseIndicator, dtype: float64
# col name:  ChronicCond_Alzheimer
# 2    59.813225
# 1    40.186775
# Name: ChronicCond_Alzheimer, dtype: float64
# col name:  ChronicCond_Heartfailure
# 1    59.042728
# 2    40.957272
# Name: ChronicCond_Heartfailure, dtype: float64
# col name:  ChronicCond_KidneyDisease
# 2    58.799809
# 1    41.200191
# Name: ChronicCond_KidneyDisease, dtype: float64
# col name:  ChronicCond_Cancer
# 2    84.861459
# 1    15.138541
# Name: ChronicCond_Cancer, dtype: float64
# col name:  ChronicCond_ObstrPulmonary
# 2    68.706994
# 1    31.293006
# Name: ChronicCond_ObstrPulmonary, dtype: float64
# col name:  ChronicCond_Depression
# 2    56.519309
# 1    43.480691
# Name: ChronicCond_Depression, dtype: float64
# col name:  ChronicCond_Diabetes
# 1    70.539456
# 2    29.460544
# ...

# %%
final_data1['RenalDiseaseIndicator'] = final_data1['RenalDiseaseIndicator'].replace('Y', 1)
final_data1['PotentialFraud'] = final_data1['PotentialFraud'].map({'Yes':1, 'No':0})

# %%
few_cols = np.setdiff1d(np.array(b_cols), np.array(['RenalDiseaseIndicator', 'PotentialFraud'])).tolist()
few_cols
# Out:
# ['ChronicCond_Alzheimer',
#  'ChronicCond_Cancer',
#  'ChronicCond_Depression',
#  'ChronicCond_Diabetes',
#  'ChronicCond_Heartfailure',
#  'ChronicCond_IschemicHeart',
#  'ChronicCond_KidneyDisease',
#  'ChronicCond_ObstrPulmonary',
#  'ChronicCond_Osteoporasis',
#  'ChronicCond_rheumatoidarthritis',
#  'ChronicCond_stroke',
#  'Gender']

# %%
for colum in few_cols:
    final_data1[colum] = final_data1[colum].replace(2,0)

# %%
for column in b_cols:
    print("col name: ", column)
    print(final_data1[column].value_counts(normalize = True)*100)
# Out:
# col name:  Gender
# 0    57.883847
# 1    42.116153
# Name: Gender, dtype: float64
# col name:  RenalDiseaseIndicator
# 0    80.32142
# 1    19.67858
# Name: RenalDiseaseIndicator, dtype: float64
# col name:  ChronicCond_Alzheimer
# 0    59.813225
# 1    40.186775
# Name: ChronicCond_Alzheimer, dtype: float64
# col name:  ChronicCond_Heartfailure
# 1    59.042728
# 0    40.957272
# Name: ChronicCond_Heartfailure, dtype: float64
# col name:  ChronicCond_KidneyDisease
# 0    58.799809
# 1    41.200191
# Name: ChronicCond_KidneyDisease, dtype: float64
# col name:  ChronicCond_Cancer
# 0    84.861459
# 1    15.138541
# Name: ChronicCond_Cancer, dtype: float64
# col name:  ChronicCond_ObstrPulmonary
# 0    68.706994
# 1    31.293006
# Name: ChronicCond_ObstrPulmonary, dtype: float64
# col name:  ChronicCond_Depression
# 0    56.519309
# 1    43.480691
# Name: ChronicCond_Depression, dtype: float64
# col name:  ChronicCond_Diabetes
# 1    70.539456
# 0    29.460544
# ...

# %%
final_data1.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE16973  CLM565430     9/6/2009    9/6/2009  PRV55912
# 2  BENE17521   CLM34721   2009-01-20  2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17  2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25  2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician ClmDiagnosisCode_1  \
# 0                   26000          PHY390922               1970
# 1                      50          PHY365867              V7183
# 2                   19000          PHY349293               4240
# 3                   17000          PHY334706              V5789
# 4                   13000          PHY390614              71535
#
#   ClmDiagnosisCode_2         DOB  Gender  Race RenalDiseaseIndicator  State  \
# 0               4019  1943-01-01       1     1                     0     39
# ...

# %%
final_data1['ClaimStartDt'] = pd.to_datetime(final_data1['ClaimStartDt'])
final_data1['ClaimEndDt'] = pd.to_datetime(final_data1['ClaimEndDt'])

# %%
np.sum(final_data1['ClaimEndDt'] == pd.NaT)
# Out:
# 0

# %%
final_data1['noofdaysforclaim'] = final_data1['ClaimEndDt'] - final_data1['ClaimStartDt']

# %%
np.sum(final_data1['noofdaysforclaim'] == pd.NaT)
# Out:
# 0

# %%
final_data1['noofdaysforclaim'] = final_data1['noofdaysforclaim'].astype(str).map(lambda x: x.split(" ")[0]).astype('int64')

# %%
final_data1.head()
# Out:
#       BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12 2009-04-18  PRV55912
# 1  BENE16973  CLM565430   2009-09-06 2009-09-06  PRV55912
# 2  BENE17521   CLM34721   2009-01-20 2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17 2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25 2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician ClmDiagnosisCode_1  \
# 0                   26000          PHY390922               1970
# 1                      50          PHY365867              V7183
# 2                   19000          PHY349293               4240
# 3                   17000          PHY334706              V5789
# 4                   13000          PHY390614              71535
#
#   ClmDiagnosisCode_2         DOB  Gender  Race RenalDiseaseIndicator  State  \
# 0               4019  1943-01-01       1     1                     0     39
# ...

# %%
final_data1['ip_op'] = final_data1['IPAnnualReimbursementAmt'] + final_data1['OPAnnualReimbursementAmt'] - final_data1['IPAnnualDeductibleAmt'] - final_data1['OPAnnualDeductibleAmt']

# %%
final_data1.head()
# Out:
#       BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12 2009-04-18  PRV55912
# 1  BENE16973  CLM565430   2009-09-06 2009-09-06  PRV55912
# 2  BENE17521   CLM34721   2009-01-20 2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17 2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25 2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician ClmDiagnosisCode_1  \
# 0                   26000          PHY390922               1970
# 1                      50          PHY365867              V7183
# 2                   19000          PHY349293               4240
# 3                   17000          PHY334706              V5789
# 4                   13000          PHY390614              71535
#
#   ClmDiagnosisCode_2         DOB  Gender  Race RenalDiseaseIndicator  State  \
# 0               4019  1943-01-01       1     1                     0     39
# ...

# %%
final_data1['total_chronic_diseases'] = final_data1['ChronicCond_Alzheimer'] + final_data1['ChronicCond_Heartfailure'] + final_data1['ChronicCond_KidneyDisease'] + final_data1['ChronicCond_Cancer'] + final_data1['ChronicCond_ObstrPulmonary']+ final_data1['ChronicCond_Depression'] + final_data1['ChronicCond_Diabetes'] + final_data1['ChronicCond_IschemicHeart']+ final_data1['ChronicCond_Osteoporasis'] + final_data1['ChronicCond_rheumatoidarthritis'] + final_data1['ChronicCond_stroke']

# %%
final_data1.head()
# Out:
#       BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12 2009-04-18  PRV55912
# 1  BENE16973  CLM565430   2009-09-06 2009-09-06  PRV55912
# 2  BENE17521   CLM34721   2009-01-20 2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17 2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25 2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician ClmDiagnosisCode_1  \
# 0                   26000          PHY390922               1970
# 1                      50          PHY365867              V7183
# 2                   19000          PHY349293               4240
# 3                   17000          PHY334706              V5789
# 4                   13000          PHY390614              71535
#
#   ClmDiagnosisCode_2         DOB  Gender  Race RenalDiseaseIndicator  State  \
# 0               4019  1943-01-01       1     1                     0     39
# ...

# %%
final_data1.shape
# Out:
# (558211, 37)

# %%
def startswith(cols):
    a =[ ]
    for i in cols:
        if i.startswith('ChronicCond_'):
            a.append(i)
    return a

# %%
l1 = startswith(final_data1.columns.tolist())
dropcols = l1 + ['ClaimStartDt','ClaimEndDt','IPAnnualReimbursementAmt','IPAnnualDeductibleAmt','OPAnnualReimbursementAmt','OPAnnualDeductibleAmt']

# %%
dropcols
# Out:
# ['ChronicCond_Alzheimer',
#  'ChronicCond_Heartfailure',
#  'ChronicCond_KidneyDisease',
#  'ChronicCond_Cancer',
#  'ChronicCond_ObstrPulmonary',
#  'ChronicCond_Depression',
#  'ChronicCond_Diabetes',
#  'ChronicCond_IschemicHeart',
#  'ChronicCond_Osteoporasis',
#  'ChronicCond_rheumatoidarthritis',
#  'ChronicCond_stroke',
#  'ClaimStartDt',
#  'ClaimEndDt',
#  'IPAnnualReimbursementAmt',
#  'IPAnnualDeductibleAmt',
#  'OPAnnualReimbursementAmt',
#  'OPAnnualDeductibleAmt']

# %%
final_data2 = final_data1.drop(dropcols, axis = 1)

# %%
final_data2.head()
# Out:
#       BeneID    ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11001   CLM46614  PRV55912                   26000          PHY390922
# 1  BENE16973  CLM565430  PRV55912                      50          PHY365867
# 2  BENE17521   CLM34721  PRV55912                   19000          PHY349293
# 3  BENE21718   CLM72336  PRV55912                   17000          PHY334706
# 4  BENE22934   CLM73394  PRV55912                   13000          PHY390614
#
#   ClmDiagnosisCode_1 ClmDiagnosisCode_2         DOB  Gender  Race  \
# 0               1970               4019  1943-01-01       1     1
# 1              V7183              53081  1932-05-01       1     1
# 2               4240               2639  1913-12-01       0     1
# 3              V5789               4168  1922-10-01       1     1
# 4              71535              71960  1930-07-01       0     1
#
#   RenalDiseaseIndicator  State  County  PotentialFraud  physician_count  \
# ...

# %%
final_data2.shape
# Out:
# (558211, 20)

# %%
final_data3 = final_data2.drop(['BeneID','ClaimID','Provider','AttendingPhysician','ClmDiagnosisCode_1','ClmDiagnosisCode_2','DOB'], axis = 1)

# %%
final_data3.head()
# Out:
#    InscClaimAmtReimbursed  Gender  Race RenalDiseaseIndicator  State  County  \
# 0                   26000       1     1                     0     39     230
# 1                      50       1     1                     0     39     310
# 2                   19000       0     1                     0     39     230
# 3                   17000       1     1                     0     39     600
# 4                   13000       0     1                     0     39     280
#
#    PotentialFraud  physician_count  provider_count  ben_count  \
# 0               1              1.0             107          3
# 1               1              1.0             107          3
# 2               1              1.0             107          2
# 3               1              2.0             107          4
# 4               1              3.0             107          7
#
#    noofdaysforclaim  ip_op  total_chronic_diseases
# 0                 6  32786                       7
# ...

# %%
final_data3.shape
# Out:
# (558211, 13)

# %%
final_data3.drop_duplicates(inplace = True)

# %%
final_data3.shape
# Out:
# (552898, 13)

# %%
X,Y = final_data3.drop('PotentialFraud', axis = 1), final_data3['PotentialFraud']

# %%
#MinMaxScaler or Normalization

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.33, stratify = Y)

# %%
from sklearn.preprocessing import MinMaxScaler
minmaxscaler = MinMaxScaler()

# %%
minmax_cols = ['InscClaimAmtReimbursed','Race','State','County','physician_count','provider_count','ben_count','noofdaysforclaim','ip_op','total_chronic_diseases']

# %%
final_data3['RenalDiseaseIndicator'].nunique()
# Out:
# 2

# %%
x_train.loc[:, minmax_cols] = minmaxscaler.fit_transform(x_train[minmax_cols])
x_test.loc[:, minmax_cols] = minmaxscaler.fit_transform(x_test[minmax_cols])
# Out:
# c:\users\ag92031\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# c:\users\ag92031\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
x_train.head()
# Out:
#         InscClaimAmtReimbursed  Gender  Race RenalDiseaseIndicator     State  \
# 534848                 0.00720       1   0.0                     0  0.830189
# 308812                 0.00048       0   0.0                     0  0.811321
# 376343                 0.00072       1   0.0                     0  0.716981
# 309720                 0.00024       1   0.0                     0  0.169811
# 518169                 0.00024       1   0.0                     1  0.264151
#
#           County  physician_count  provider_count  ben_count  \
# 534848  0.610611         0.000000        0.002792   0.071429
# 308812  0.500501         0.001579        0.052798   0.250000
# 376343  0.770771         0.018950        0.079136   0.071429
# 309720  0.020020         0.171733        0.211433   0.071429
# 518169  0.790791         0.003158        0.012987   0.500000
#
#         noofdaysforclaim     ip_op  total_chronic_diseases
# 534848               0.0  0.170974                0.454545
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
print("accuracy on test data: ", lr.score(x_test, y_test))
# Out:
# accuracy on test data:  0.8096976273861787

# %%
print("accuracy on test data: ", lr.score(x_train, y_train))
# Out:
# accuracy on test data:  0.808161083681342

# %%
dt = DecisionTreeClassifier(max_depth = 250, min_samples_split = 70, criterion = 'gini')

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=250, min_samples_split=70)

# %%
print("accuracy on test data: ", dt.score(x_test, y_test))
# Out:
# accuracy on test data:  0.9654987202464143

# %%
print("accuracy on test data: ", dt.score(x_train, y_train))
# Out:
# accuracy on test data:  0.9734829568001382

# %%
#confusion matrix
#r1 score
#roc curve 
#graphs (trainings and accuracies)
#K-fold cross validation 
#hyper-parameter tuning (gridsearchcv, randomizedcv)
#pair plots, distribution plots, count plots, groupby, correlation matrix, heatmap

# %%
from sklearn.metrics import roc_auc_score, roc_curve, f1_score, confusion_matrix, classification_report
from sklearn.model_selection import RandomizedSearchCV

# %%
dt.predict_proba(x_test).shape
# Out:
# (182457, 2)

# %%
y_test.shape
# Out:
# (182457,)

# %%
predictions = dt.predict_proba(x_test)[:,1]

# %%
predictions
# Out:
# array([0.        , 0.01960784, 1.        , ..., 1.        , 1.        ,
#        1.        ])

# %%
predictions.shape
# Out:
# (182457,)

# %%
y_pred = np.array([1 if (val>0.6) else 0 for val in predictions])

# %%
y_pred
# Out:
# array([0, 0, 1, ..., 1, 1, 1])

# %%
y_test
# Out:
# 112790    0
# 145462    0
# 99067     1
# 135132    0
# 480482    0
#          ..
# 442870    0
# 125780    1
# 97467     1
# 300698    1
# 18740     1
# Name: PotentialFraud, Length: 182457, dtype: int64

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[111238   1623]
#  [  4211  65385]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97    112861
#            1       0.98      0.94      0.96     69596
#
#     accuracy                           0.97    182457
#    macro avg       0.97      0.96      0.97    182457
# weighted avg       0.97      0.97      0.97    182457

# %%
# precision   -  TP/TP + FP

# recall  - TP / TP + FN

# f1 - score   - 2 PR/(P+R)

# %%
a = 111238/(111238+4211)

# %%
b = 111238/(111238+1623)

# %%
2*a*b/(a+b)
# Out:
# 0.9744470237834524

# %%
from sklearn.tree import plot_tree

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 16))
plot_tree(dt, filled  =True, fontsize = 5)
# Out:
# [Text(461.8731718090336, 856.9694117647059, 'X[7] <= 0.148\ngini = 0.472\nsamples = 370441\nvalue = [229141, 141300]'),
#  Text(369.256107194163, 831.3882352941176, 'X[7] <= 0.029\ngini = 0.343\nsamples = 292499\nvalue = [228278, 64221]'),
#  Text(220.83710350147456, 805.8070588235294, 'X[0] <= 0.031\ngini = 0.212\nsamples = 149427\nvalue = [131433, 17994]'),
#  Text(137.40116788217674, 780.2258823529412, 'X[7] <= 0.012\ngini = 0.164\nsamples = 135571\nvalue = [123366, 12205]'),
#  Text(55.394404370336396, 754.6447058823529, 'X[7] <= 0.005\ngini = 0.093\nsamples = 70577\nvalue = [67108, 3469]'),
#  Text(21.46307883632536, 729.0635294117646, 'X[9] <= 0.569\ngini = 0.039\nsamples = 24985\nvalue = [24494, 491]'),
#  Text(21.256669583975135, 703.4823529411765, 'X[0] <= 0.023\ngini = 0.038\nsamples = 24973\nvalue = [24489, 484]'),
#  Text(12.92102518452104, 677.9011764705882, 'X[7] <= 0.002\ngini = 0.034\nsamples = 24244\nvalue = [23821, 423]'),
# ...
