# %%
#Business problem statement + Data Merging
1. Inpatient + Outpatient = final_patient
2. final_patient + train = fp_v1
3. fp_v1 + beneficiary data = final data

# %%
# data merging
# EDA (Missing values, graphs, plots)
# Outlier treatments, Imputations
# Feature engineering
# Model Building
# Model Training 
# Model Evaluation

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
inpatient_data = pd.read_csv('Train_Inpatientdata.csv')
train = pd.read_csv('Train.csv')
ben_data = pd.read_csv('Train_Beneficiarydata.csv')

# %%
outpatient_data = pd.read_csv('Train_Outpatientdata.csv')

# %%
inpatient_data.describe()
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid  ClmProcedureCode_1  \
# count            40474.000000            39575.0        23148.000000
# mean             10087.884074             1068.0         5894.611759
# std              10303.099402                0.0         3049.304400
# min                  0.000000             1068.0           11.000000
# 25%               4000.000000             1068.0         3848.000000
# 50%               7000.000000             1068.0         5369.000000
# 75%              12000.000000             1068.0         8666.250000
# max             125000.000000             1068.0         9999.000000
#
#        ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# count         5454.000000          965.000000          116.000000
# mean          4103.738174         4226.355440         4070.172414
# std           2028.182156         2282.761581         1994.409802
# min             42.000000           42.000000           42.000000
# ...

# %%
inpatient_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40474 entries, 0 to 40473
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   BeneID                  40474 non-null  object
#  1   ClaimID                 40474 non-null  object
#  2   ClaimStartDt            40474 non-null  object
#  3   ClaimEndDt              40474 non-null  object
#  4   Provider                40474 non-null  object
#  5   InscClaimAmtReimbursed  40474 non-null  int64
#  6   AttendingPhysician      40362 non-null  object
#  7   OperatingPhysician      23830 non-null  object
#  8   OtherPhysician          4690 non-null   object
#  9   AdmissionDt             40474 non-null  object
#  10  ClmAdmitDiagnosisCode   40474 non-null  object
#  11  DeductibleAmtPaid       39575 non-null  float64
#  12  DischargeDt             40474 non-null  object
#  13  DiagnosisGroupCode      40474 non-null  object
# ...

# %%
40000, 
0 non-null in a column
no of null = no of rows - no of non null
          = 40000 - 0 = 40000

# %%
inpatient_data.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-04-12  ...               2724               19889
# 1            NaN  2009-08-31  ...                NaN                 NaN
# ...

# %%
outpatient_data.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0            NaN              78943  ...                NaN
# 1            NaN               6115  ...                NaN
# ...

# %%
outpatient_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517737 entries, 0 to 517736
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   BeneID                  517737 non-null  object
#  1   ClaimID                 517737 non-null  object
#  2   ClaimStartDt            517737 non-null  object
#  3   ClaimEndDt              517737 non-null  object
#  4   Provider                517737 non-null  object
#  5   InscClaimAmtReimbursed  517737 non-null  int64
#  6   AttendingPhysician      516341 non-null  object
#  7   OperatingPhysician      90617 non-null   object
#  8   OtherPhysician          195046 non-null  object
#  9   ClmDiagnosisCode_1      507284 non-null  object
#  10  ClmDiagnosisCode_2      322357 non-null  object
#  11  ClmDiagnosisCode_3      203257 non-null  object
#  12  ClmDiagnosisCode_4      125596 non-null  object
#  13  ClmDiagnosisCode_5      74344 non-null   object
# ...

# %%
train.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5410 entries, 0 to 5409
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provider        5410 non-null   object
#  1   PotentialFraud  5410 non-null   object
# dtypes: object(2)
# memory usage: 84.7+ KB

# %%
ben_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138556 entries, 0 to 138555
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           138556 non-null  object
#  1   DOB                              138556 non-null  object
#  2   DOD                              1421 non-null    object
#  3   Gender                           138556 non-null  int64
#  4   Race                             138556 non-null  int64
#  5   RenalDiseaseIndicator            138556 non-null  object
#  6   State                            138556 non-null  int64
#  7   County                           138556 non-null  int64
#  8   NoOfMonths_PartACov              138556 non-null  int64
#  9   NoOfMonths_PartBCov              138556 non-null  int64
#  10  ChronicCond_Alzheimer            138556 non-null  int64
# ...

# %%
ben_data.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0     230                   12                   12  ...
# 1     280                   12                   12  ...
# 2     590                   12                   12  ...
# 3     270                   12                   12  ...
# 4     680                   12                   12  ...
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# 0                       1                     1                          1
# ...

# %%
final_patient_data = pd.merge(inpatient_data, outpatient_data, )

# %%
len(inpatient_data.columns.tolist())
# Out:
# 30

# %%
len(outpatient_data.columns.tolist())
# Out:
# 27

# %%
len([col_name for col_name in outpatient_data.columns.tolist() if col_name in inpatient_data.columns.tolist()])
# Out:
# 27

# %%
final_patient = pd.merge(inpatient_data, outpatient_data, 
left_on = [col for col in outpatient_data.columns if col in inpatient_data.columns],
right_on = [col for col in outpatient_data.columns if col in inpatient_data.columns]
, how = 'outer') #inner join, outer join(NA)

# %%
outpatient_data.shape
# Out:
# (517737, 27)

# %%
inpatient_data.shape
# Out:
# (40474, 30)

# %%
final_patient.shape
# Out:
# (558211, 30)

# %%
pd.set_option("display.max_columns", None)

# %%
final_patient.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# ...

# %%
final_patient['BeneID'].nunique()
# Out:
# 138556

# %%
ben_data['BeneID'].nunique()
# Out:
# 138556

# %%
ben_data.shape
# Out:
# (138556, 25)

# %%
final_ben = pd.merge(final_patient, ben_data, on = 'BeneID', how = 'inner')

# %%
final_ben.shape
# Out:
# (558211, 54)

# %%
final_ben.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11011  CLM144521   2009-01-18  2009-01-18  PRV52314
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                      50          PHY379398                NaN
#
#   OtherPhysician AdmissionDt  ... ChronicCond_Depression  \
# 0            NaN  2009-04-12  ...                      1
# 1            NaN  2009-08-31  ...                      1
# ...

# %%
train['Provider'].nunique()
# Out:
# 5410

# %%
final_ben['Provider'].nunique()
# Out:
# 5410

# %%
final_ben.shape
# Out:
# (558211, 54)

# %%
final_data = pd.merge(final_ben, train, on = 'Provider', how = 'outer')

# %%
final_data.shape
# Out:
# (558211, 55)

# %%
final_data.head().transpose()
# Out:
#                                           0           1           2  \
# BeneID                            BENE11001   BENE16973   BENE17521
# ClaimID                            CLM46614   CLM565430    CLM34721
# ClaimStartDt                     2009-04-12  2009-09-06  2009-01-20
# ClaimEndDt                       2009-04-18  2009-09-06  2009-02-01
# Provider                           PRV55912    PRV55912    PRV55912
# InscClaimAmtReimbursed                26000          50       19000
# AttendingPhysician                PHY390922   PHY365867   PHY349293
# OperatingPhysician                      NaN   PHY327147   PHY370861
# OtherPhysician                          NaN         NaN   PHY363291
# AdmissionDt                      2009-04-12         NaN  2009-01-20
# ClmAdmitDiagnosisCode                  7866         NaN       45340
# DeductibleAmtPaid                      1068           0        1068
# DischargeDt                      2009-04-18         NaN  2009-02-01
# ...

# %%
level binarizer

# %%
final_data['PotentialFraud'].value_counts()/len(final_data)*100
# Out:
# No     61.878931
# Yes    38.121069
# Name: PotentialFraud, dtype: float64

# %%
final_data['PotentialFraud'].value_counts(normalize = True)*100
# Out:
# No     61.878931
# Yes    38.121069
# Name: PotentialFraud, dtype: float64

# %%
for col in final_data.columns.tolist():
    print(final_data[col].value_counts())
# Out:
# BENE42721     29
# BENE118316    29
# BENE59303     29
# BENE36330     28
# BENE80977     28
#               ..
# BENE42162      1
# BENE48938      1
# BENE101641     1
# BENE147133     1
# BENE73784      1
# Name: BeneID, Length: 138556, dtype: int64
# CLM34301     1
# CLM671891    1
# CLM326576    1
# CLM253077    1
# CLM64044     1
#             ..
# CLM653309    1
# CLM593607    1
# CLM525409    1
# CLM585385    1
# CLM695831    1
# Name: ClaimID, Length: 558211, dtype: int64
# 2009-01-31    1709
# 2009-03-03    1706
# 2009-03-21    1677
# 2009-03-08    1676
# 2009-04-04    1667
#               ...
# 2008-11-29       2
# 2008-11-27       2
# 2008-12-06       1
# 2008-12-10       1
# 2008-12-03       1
# Name: ClaimStartDt, Length: 398, dtype: int64
# 2009-03-03    1707
# 2009-02-11    1682
# 2009-05-01    1678
# 2009-03-08    1672
# 2009-03-21    1668
#               ...
# 2009-12-20    1271
# 2009-12-21    1268
# 2009-12-29    1267
# 2009-12-22    1256
# 2008-12-28       1
# ...

# %%
final_data['ClmProcedureCode_6'].value_counts() #col 2 be removed
# Out:
# Series([], Name: ClmProcedureCode_6, dtype: int64)

# %%
DATASET1
A 2
B 23

DATASET2
A 20
B 15
C 20

INNER JOIN
A 2
B 3

OUTER JOIN
A 20
B 15
C NA

# %%
#JOINS (INNER, OUTER, LEFT, RIGHT)
